# %%
import pandas as pd

# %%
df = pd.read_csv("fraud_oracle.csv")

# %%
df.head()
# Out:
#   Month  WeekOfMonth  DayOfWeek    Make AccidentArea DayOfWeekClaimed  \
# 0   Dec            5  Wednesday   Honda        Urban          Tuesday
# 1   Jan            3  Wednesday   Honda        Urban           Monday
# 2   Oct            5     Friday   Honda        Urban         Thursday
# 3   Jun            2   Saturday  Toyota        Rural           Friday
# 4   Jan            5     Monday   Honda        Urban          Tuesday
#
#   MonthClaimed  WeekOfMonthClaimed     Sex MaritalStatus  ...  AgeOfVehicle  \
# 0          Jan                   1  Female        Single  ...       3 years
# 1          Jan                   4    Male        Single  ...       6 years
# 2          Nov                   2    Male       Married  ...       7 years
# 3          Jul                   1    Male       Married  ...   more than 7
# 4          Feb                   2  Female        Single  ...       5 years
#
#   AgeOfPolicyHolder PoliceReportFiled WitnessPresent AgentType  \
# ...

# %%
df.isnull().sum()
# Out:
# Month                   0
# WeekOfMonth             0
# DayOfWeek               0
# Make                    0
# AccidentArea            0
# DayOfWeekClaimed        0
# MonthClaimed            0
# WeekOfMonthClaimed      0
# Sex                     0
# MaritalStatus           0
# Age                     0
# Fault                   0
# PolicyType              0
# VehicleCategory         0
# VehiclePrice            0
# FraudFound_P            0
# PolicyNumber            0
# RepNumber               0
# Deductible              0
# DriverRating            0
# Days_Policy_Accident    0
# Days_Policy_Claim       0
# PastNumberOfClaims      0
# AgeOfVehicle            0
# AgeOfPolicyHolder       0
# PoliceReportFiled       0
# WitnessPresent          0
# AgentType               0
# NumberOfSuppliments     0
# AddressChange_Claim     0
# NumberOfCars            0
# Year                    0
# BasePolicy              0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15420 entries, 0 to 15419
# Data columns (total 33 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Month                 15420 non-null  object
#  1   WeekOfMonth           15420 non-null  int64
#  2   DayOfWeek             15420 non-null  object
#  3   Make                  15420 non-null  object
#  4   AccidentArea          15420 non-null  object
#  5   DayOfWeekClaimed      15420 non-null  object
#  6   MonthClaimed          15420 non-null  object
#  7   WeekOfMonthClaimed    15420 non-null  int64
#  8   Sex                   15420 non-null  object
#  9   MaritalStatus         15420 non-null  object
#  10  Age                   15420 non-null  int64
#  11  Fault                 15420 non-null  object
#  12  PolicyType            15420 non-null  object
#  13  VehicleCategory       15420 non-null  object
#  14  VehiclePrice          15420 non-null  object
# ...

# %%
df.head(2)
# Out:
#   Month  WeekOfMonth  DayOfWeek   Make AccidentArea DayOfWeekClaimed  \
# 0   Dec            5  Wednesday  Honda        Urban          Tuesday
# 1   Jan            3  Wednesday  Honda        Urban           Monday
#
#   MonthClaimed  WeekOfMonthClaimed     Sex MaritalStatus  ...  AgeOfVehicle  \
# 0          Jan                   1  Female        Single  ...       3 years
# 1          Jan                   4    Male        Single  ...       6 years
#
#   AgeOfPolicyHolder PoliceReportFiled WitnessPresent AgentType  \
# 0          26 to 30                No             No  External
# 1          31 to 35               Yes             No  External
#
#    NumberOfSuppliments  AddressChange_Claim  NumberOfCars  Year  BasePolicy
# 0                 none               1 year        3 to 4  1994   Liability
# 1                 none            no change     1 vehicle  1994   Collision
#
# [2 rows x 33 columns]

# %%
df.DayOfWeek.value_counts()
# Out:
# Monday       2616
# Friday       2445
# Tuesday      2300
# Thursday     2173
# Wednesday    2159
# Saturday     1982
# Sunday       1745
# Name: DayOfWeek, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
dayEncoder = LabelEncoder().fit(df.DayOfWeek)

# %%
df.DayOfWeek = dayEncoder.transform(df.DayOfWeek)

# %%
df.columns
# Out:
# Index(['Month', 'WeekOfMonth', 'DayOfWeek', 'Make', 'AccidentArea',
#        'DayOfWeekClaimed', 'MonthClaimed', 'WeekOfMonthClaimed', 'Sex',
#        'MaritalStatus', 'Age', 'Fault', 'PolicyType', 'VehicleCategory',
#        'VehiclePrice', 'FraudFound_P', 'PolicyNumber', 'RepNumber',
#        'Deductible', 'DriverRating', 'Days_Policy_Accident',
#        'Days_Policy_Claim', 'PastNumberOfClaims', 'AgeOfVehicle',
#        'AgeOfPolicyHolder', 'PoliceReportFiled', 'WitnessPresent', 'AgentType',
#        'NumberOfSuppliments', 'AddressChange_Claim', 'NumberOfCars', 'Year',
#        'BasePolicy'],
#       dtype='object')

# %%
df.DayOfWeekClaimed.value_counts()
# Out:
# Monday       3757
# Tuesday      3375
# Wednesday    2951
# Thursday     2660
# Friday       2497
# Saturday      127
# Sunday         52
# 0               1
# Name: DayOfWeekClaimed, dtype: int64

# %%
df.shape
# Out:
# (15420, 33)

# %%
df = df[df['DayOfWeekClaimed']!='0']

# %%
df.shape
# Out:
# (15419, 33)

# %%
df.DayOfWeekClaimed = dayEncoder.transform(df.DayOfWeekClaimed)

# %%
df.Month.value_counts()
# Out:
# Jan    1411
# May    1367
# Mar    1360
# Jun    1321
# Oct    1305
# Dec    1285
# Apr    1280
# Feb    1266
# Jul    1256
# Sep    1240
# Nov    1201
# Aug    1127
# Name: Month, dtype: int64

# %%
monthEncoder = LabelEncoder().fit(df.Month)

# %%
df.Month = monthEncoder.transform(df.Month)

# %%
df.columns
# Out:
# Index(['Month', 'WeekOfMonth', 'DayOfWeek', 'Make', 'AccidentArea',
#        'DayOfWeekClaimed', 'MonthClaimed', 'WeekOfMonthClaimed', 'Sex',
#        'MaritalStatus', 'Age', 'Fault', 'PolicyType', 'VehicleCategory',
#        'VehiclePrice', 'FraudFound_P', 'PolicyNumber', 'RepNumber',
#        'Deductible', 'DriverRating', 'Days_Policy_Accident',
#        'Days_Policy_Claim', 'PastNumberOfClaims', 'AgeOfVehicle',
#        'AgeOfPolicyHolder', 'PoliceReportFiled', 'WitnessPresent', 'AgentType',
#        'NumberOfSuppliments', 'AddressChange_Claim', 'NumberOfCars', 'Year',
#        'BasePolicy'],
#       dtype='object')

# %%
df.head(2)
# Out:
#    Month  WeekOfMonth  DayOfWeek   Make AccidentArea  DayOfWeekClaimed  \
# 0      2            5          6  Honda        Urban                 5
# 1      4            3          6  Honda        Urban                 1
#
#   MonthClaimed  WeekOfMonthClaimed     Sex MaritalStatus  ...  AgeOfVehicle  \
# 0          Jan                   1  Female        Single  ...       3 years
# 1          Jan                   4    Male        Single  ...       6 years
#
#   AgeOfPolicyHolder PoliceReportFiled WitnessPresent AgentType  \
# 0          26 to 30                No             No  External
# 1          31 to 35               Yes             No  External
#
#    NumberOfSuppliments  AddressChange_Claim  NumberOfCars  Year  BasePolicy
# 0                 none               1 year        3 to 4  1994   Liability
# 1                 none            no change     1 vehicle  1994   Collision
#
# [2 rows x 33 columns]

# %%
df.Make.value_counts()
# Out:
# Pontiac      3837
# Toyota       3121
# Honda        2800
# Mazda        2354
# Chevrolet    1681
# Accura        472
# Ford          450
# VW            283
# Dodge         109
# Saab          108
# Mercury        83
# Saturn         58
# Nisson         30
# BMW            15
# Jaguar          6
# Porche          5
# Mecedes         4
# Ferrari         2
# Lexus           1
# Name: Make, dtype: int64

# %%
df.shape
# Out:
# (15419, 33)

# %%
df = df[df['Make'] != 'Jaguar']
df = df[df['Make'] != 'Porche']
df = df[df['Make'] != 'Mecedes']
df = df[df['Make'] != 'Ferrari']
df = df[df['Make'] != 'Lexus']

# %%
df.shape
# Out:
# (15401, 33)

# %%
makerEncoder = LabelEncoder().fit(df.Make)

# %%
df.Make = makerEncoder.transform(df.Make)

# %%
df.head(2)
# Out:
#    Month  WeekOfMonth  DayOfWeek  Make AccidentArea  DayOfWeekClaimed  \
# 0      2            5          6     5        Urban                 5
# 1      4            3          6     5        Urban                 1
#
#   MonthClaimed  WeekOfMonthClaimed     Sex MaritalStatus  ...  AgeOfVehicle  \
# 0          Jan                   1  Female        Single  ...       3 years
# 1          Jan                   4    Male        Single  ...       6 years
#
#   AgeOfPolicyHolder PoliceReportFiled WitnessPresent AgentType  \
# 0          26 to 30                No             No  External
# 1          31 to 35               Yes             No  External
#
#    NumberOfSuppliments  AddressChange_Claim  NumberOfCars  Year  BasePolicy
# 0                 none               1 year        3 to 4  1994   Liability
# 1                 none            no change     1 vehicle  1994   Collision
#
# [2 rows x 33 columns]

# %%
df.columns
# Out:
# Index(['Month', 'WeekOfMonth', 'DayOfWeek', 'Make', 'AccidentArea',
#        'DayOfWeekClaimed', 'MonthClaimed', 'WeekOfMonthClaimed', 'Sex',
#        'MaritalStatus', 'Age', 'Fault', 'PolicyType', 'VehicleCategory',
#        'VehiclePrice', 'FraudFound_P', 'PolicyNumber', 'RepNumber',
#        'Deductible', 'DriverRating', 'Days_Policy_Accident',
#        'Days_Policy_Claim', 'PastNumberOfClaims', 'AgeOfVehicle',
#        'AgeOfPolicyHolder', 'PoliceReportFiled', 'WitnessPresent', 'AgentType',
#        'NumberOfSuppliments', 'AddressChange_Claim', 'NumberOfCars', 'Year',
#        'BasePolicy'],
#       dtype='object')

# %%
df.AccidentArea.value_counts()
# Out:
# Urban    13809
# Rural     1592
# Name: AccidentArea, dtype: int64

# %%
areaEncoder = LabelEncoder().fit(df.AccidentArea)
df.AccidentArea = areaEncoder.transform(df.AccidentArea)

# %%
df.MonthClaimed = monthEncoder.transform(df.MonthClaimed)

# %%
sexEncoder = LabelEncoder().fit(df.Sex)
df.Sex = sexEncoder.transform(df.Sex)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15401 entries, 0 to 15419
# Data columns (total 33 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Month                 15401 non-null  int64
#  1   WeekOfMonth           15401 non-null  int64
#  2   DayOfWeek             15401 non-null  int64
#  3   Make                  15401 non-null  int64
#  4   AccidentArea          15401 non-null  int64
#  5   DayOfWeekClaimed      15401 non-null  int64
#  6   MonthClaimed          15401 non-null  int64
#  7   WeekOfMonthClaimed    15401 non-null  int64
#  8   Sex                   15401 non-null  int64
#  9   MaritalStatus         15401 non-null  object
#  10  Age                   15401 non-null  int64
#  11  Fault                 15401 non-null  object
#  12  PolicyType            15401 non-null  object
#  13  VehicleCategory       15401 non-null  object
#  14  VehiclePrice          15401 non-null  object
# ...

# %%
df.MaritalStatus.value_counts()
# Out:
# Married     10611
# Single       4679
# Divorced       76
# Widow          35
# Name: MaritalStatus, dtype: int64

# %%
maritalEncoder = LabelEncoder().fit(df.MaritalStatus)
df.MaritalStatus = maritalEncoder.transform(df.MaritalStatus)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15401 entries, 0 to 15419
# Data columns (total 33 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Month                 15401 non-null  int64
#  1   WeekOfMonth           15401 non-null  int64
#  2   DayOfWeek             15401 non-null  int64
#  3   Make                  15401 non-null  int64
#  4   AccidentArea          15401 non-null  int64
#  5   DayOfWeekClaimed      15401 non-null  int64
#  6   MonthClaimed          15401 non-null  int64
#  7   WeekOfMonthClaimed    15401 non-null  int64
#  8   Sex                   15401 non-null  int64
#  9   MaritalStatus         15401 non-null  int64
#  10  Age                   15401 non-null  int64
#  11  Fault                 15401 non-null  object
#  12  PolicyType            15401 non-null  object
#  13  VehicleCategory       15401 non-null  object
#  14  VehiclePrice          15401 non-null  object
# ...

# %%
df.PolicyType.value_counts()
# Out:
# Sedan - Collision       5580
# Sedan - Liability       4982
# Sedan - All Perils      4082
# Sport - Collision        348
# Utility - All Perils     339
# Utility - Collision       26
# Sport - All Perils        22
# Utility - Liability       21
# Sport - Liability          1
# Name: PolicyType, dtype: int64

# %%
df = df[df['PolicyType']!='Sport - Liability']
df = df[df['PolicyType']!='Utility - Collision']
df = df[df['PolicyType']!='Sport - All Perils']
df = df[df['PolicyType']!='Utility - Liability']

# %%
df.PolicyType.value_counts()
# Out:
# Sedan - Collision       5580
# Sedan - Liability       4982
# Sedan - All Perils      4082
# Sport - Collision        348
# Utility - All Perils     339
# Name: PolicyType, dtype: int64

# %%
df.shape
# Out:
# (15331, 33)

# %%
policyEncoder = LabelEncoder().fit(df.PolicyType)
df.PolicyType = policyEncoder.transform(df.PolicyType)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15331 entries, 1 to 15419
# Data columns (total 33 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Month                 15331 non-null  int64
#  1   WeekOfMonth           15331 non-null  int64
#  2   DayOfWeek             15331 non-null  int64
#  3   Make                  15331 non-null  int64
#  4   AccidentArea          15331 non-null  int64
#  5   DayOfWeekClaimed      15331 non-null  int64
#  6   MonthClaimed          15331 non-null  int64
#  7   WeekOfMonthClaimed    15331 non-null  int64
#  8   Sex                   15331 non-null  int64
#  9   MaritalStatus         15331 non-null  int64
#  10  Age                   15331 non-null  int64
#  11  Fault                 15331 non-null  object
#  12  PolicyType            15331 non-null  int64
#  13  VehicleCategory       15331 non-null  object
#  14  VehiclePrice          15331 non-null  object
# ...

# %%
df.Fault.value_counts()
# Out:
# Policy Holder    11152
# Third Party       4179
# Name: Fault, dtype: int64

# %%
policyHolderEncoder = LabelEncoder().fit(df.Fault)
df.Fault = policyHolderEncoder.transform(df.Fault)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15331 entries, 1 to 15419
# Data columns (total 33 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Month                 15331 non-null  int64
#  1   WeekOfMonth           15331 non-null  int64
#  2   DayOfWeek             15331 non-null  int64
#  3   Make                  15331 non-null  int64
#  4   AccidentArea          15331 non-null  int64
#  5   DayOfWeekClaimed      15331 non-null  int64
#  6   MonthClaimed          15331 non-null  int64
#  7   WeekOfMonthClaimed    15331 non-null  int64
#  8   Sex                   15331 non-null  int64
#  9   MaritalStatus         15331 non-null  int64
#  10  Age                   15331 non-null  int64
#  11  Fault                 15331 non-null  int64
#  12  PolicyType            15331 non-null  int64
#  13  VehicleCategory       15331 non-null  object
#  14  VehiclePrice          15331 non-null  object
# ...

# %%
df.VehicleCategory.value_counts()
# Out:
# Sedan      9662
# Sport      5330
# Utility     339
# Name: VehicleCategory, dtype: int64

# %%
vehCatEncoder = LabelEncoder().fit(df.VehicleCategory)

# %%
df.VehicleCategory = vehCatEncoder.transform(df.VehicleCategory)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15331 entries, 1 to 15419
# Data columns (total 33 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Month                 15331 non-null  int64
#  1   WeekOfMonth           15331 non-null  int64
#  2   DayOfWeek             15331 non-null  int64
#  3   Make                  15331 non-null  int64
#  4   AccidentArea          15331 non-null  int64
#  5   DayOfWeekClaimed      15331 non-null  int64
#  6   MonthClaimed          15331 non-null  int64
#  7   WeekOfMonthClaimed    15331 non-null  int64
#  8   Sex                   15331 non-null  int64
#  9   MaritalStatus         15331 non-null  int64
#  10  Age                   15331 non-null  int64
#  11  Fault                 15331 non-null  int64
#  12  PolicyType            15331 non-null  int64
#  13  VehicleCategory       15331 non-null  int64
#  14  VehiclePrice          15331 non-null  object
# ...

# %%
df.VehiclePrice.value_counts()
# Out:
# 20000 to 29000     8072
# 30000 to 39000     3525
# more than 69000    2104
# less than 20000    1093
# 40000 to 59000      451
# 60000 to 69000       86
# Name: VehiclePrice, dtype: int64

# %%
vehPriceEncoder = LabelEncoder().fit(df.VehiclePrice)

# %%
df.VehiclePrice = vehPriceEncoder.transform(df.VehiclePrice)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15331 entries, 1 to 15419
# Data columns (total 33 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Month                 15331 non-null  int64
#  1   WeekOfMonth           15331 non-null  int64
#  2   DayOfWeek             15331 non-null  int64
#  3   Make                  15331 non-null  int64
#  4   AccidentArea          15331 non-null  int64
#  5   DayOfWeekClaimed      15331 non-null  int64
#  6   MonthClaimed          15331 non-null  int64
#  7   WeekOfMonthClaimed    15331 non-null  int64
#  8   Sex                   15331 non-null  int64
#  9   MaritalStatus         15331 non-null  int64
#  10  Age                   15331 non-null  int64
#  11  Fault                 15331 non-null  int64
#  12  PolicyType            15331 non-null  int64
#  13  VehicleCategory       15331 non-null  int64
#  14  VehiclePrice          15331 non-null  int64
# ...

# %%
df.Days_Policy_Accident.value_counts()
# Out:
# more than 30    15158
# none               55
# 8 to 15            55
# 15 to 30           49
# 1 to 7             14
# Name: Days_Policy_Accident, dtype: int64

# %%
# df = df[df['Days_Policy_Accident']!='none']

# %%
df.Days_Policy_Accident.value_counts()
# Out:
# more than 30    15158
# none               55
# 8 to 15            55
# 15 to 30           49
# 1 to 7             14
# Name: Days_Policy_Accident, dtype: int64

# %%
df.Days_Policy_Claim.value_counts()
# Out:
# more than 30    15254
# 15 to 30           56
# 8 to 15            21
# Name: Days_Policy_Claim, dtype: int64

# %%
daysCalimEncoder.classes_
# Out:
# array(['1 to 7', '15 to 30', '8 to 15', 'more than 30', 'none'],
#       dtype=object)

# %%
daysCalimEncoder = LabelEncoder().fit(df.Days_Policy_Accident)
df.Days_Policy_Accident = daysCalimEncoder.transform(df.Days_Policy_Accident)
df.Days_Policy_Claim = daysCalimEncoder.transform(df.Days_Policy_Claim)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15331 entries, 1 to 15419
# Data columns (total 33 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Month                 15331 non-null  int64
#  1   WeekOfMonth           15331 non-null  int64
#  2   DayOfWeek             15331 non-null  int64
#  3   Make                  15331 non-null  int64
#  4   AccidentArea          15331 non-null  int64
#  5   DayOfWeekClaimed      15331 non-null  int64
#  6   MonthClaimed          15331 non-null  int64
#  7   WeekOfMonthClaimed    15331 non-null  int64
#  8   Sex                   15331 non-null  int64
#  9   MaritalStatus         15331 non-null  int64
#  10  Age                   15331 non-null  int64
#  11  Fault                 15331 non-null  int64
#  12  PolicyType            15331 non-null  int64
#  13  VehicleCategory       15331 non-null  int64
#  14  VehiclePrice          15331 non-null  int64
# ...

# %%
df.BasePolicy.value_counts()
# Out:
# Collision     5928
# Liability     4982
# All Perils    4421
# Name: BasePolicy, dtype: int64

# %%
baseEncoder = LabelEncoder().fit(df.BasePolicy)
df.BasePolicy = baseEncoder.transform(df.BasePolicy)

# %%
df.PastNumberOfClaims.value_counts()
# Out:
# 2 to 4         5453
# none           4328
# 1              3557
# more than 4    1993
# Name: PastNumberOfClaims, dtype: int64

# %%
pastClaimsEncoder = LabelEncoder().fit(df.PastNumberOfClaims)
df.PastNumberOfClaims = pastClaimsEncoder.transform(df.PastNumberOfClaims)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15331 entries, 1 to 15419
# Data columns (total 33 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Month                 15331 non-null  int64
#  1   WeekOfMonth           15331 non-null  int64
#  2   DayOfWeek             15331 non-null  int64
#  3   Make                  15331 non-null  int64
#  4   AccidentArea          15331 non-null  int64
#  5   DayOfWeekClaimed      15331 non-null  int64
#  6   MonthClaimed          15331 non-null  int64
#  7   WeekOfMonthClaimed    15331 non-null  int64
#  8   Sex                   15331 non-null  int64
#  9   MaritalStatus         15331 non-null  int64
#  10  Age                   15331 non-null  int64
#  11  Fault                 15331 non-null  int64
#  12  PolicyType            15331 non-null  int64
#  13  VehicleCategory       15331 non-null  int64
#  14  VehiclePrice          15331 non-null  int64
# ...

# %%
df.AgeOfVehicle.value_counts()
# Out:
# 7 years        5777
# more than 7    3946
# 6 years        3441
# 5 years        1353
# new             362
# 4 years         229
# 3 years         150
# 2 years          73
# Name: AgeOfVehicle, dtype: int64

# %%
df.AgeOfPolicyHolder.value_counts()
# Out:
# 31 to 35    5584
# 36 to 40    4017
# 41 to 50    2805
# 51 to 65    1377
# 26 to 30     611
# over 65      504
# 16 to 17     310
# 21 to 25     108
# 18 to 20      15
# Name: AgeOfPolicyHolder, dtype: int64

# %%
vehicleAgeEncoder = LabelEncoder().fit(df.AgeOfVehicle)
df.AgeOfVehicle = vehicleAgeEncoder.transform(df.AgeOfVehicle) 

policyHolderAgeEncoder = LabelEncoder().fit(df.AgeOfPolicyHolder)
df.AgeOfPolicyHolder = policyHolderAgeEncoder.transform(df.AgeOfPolicyHolder)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15331 entries, 1 to 15419
# Data columns (total 33 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Month                 15331 non-null  int64
#  1   WeekOfMonth           15331 non-null  int64
#  2   DayOfWeek             15331 non-null  int64
#  3   Make                  15331 non-null  int64
#  4   AccidentArea          15331 non-null  int64
#  5   DayOfWeekClaimed      15331 non-null  int64
#  6   MonthClaimed          15331 non-null  int64
#  7   WeekOfMonthClaimed    15331 non-null  int64
#  8   Sex                   15331 non-null  int64
#  9   MaritalStatus         15331 non-null  int64
#  10  Age                   15331 non-null  int64
#  11  Fault                 15331 non-null  int64
#  12  PolicyType            15331 non-null  int64
#  13  VehicleCategory       15331 non-null  int64
#  14  VehiclePrice          15331 non-null  int64
# ...

# %%
df.PoliceReportFiled .value_counts()
# Out:
# No     14906
# Yes      425
# Name: PoliceReportFiled, dtype: int64

# %%
yesNoEncoder = LabelEncoder().fit(df.PoliceReportFiled)

# %%
df.PoliceReportFiled = yesNoEncoder.transform(df.PoliceReportFiled)

# %%
df.WitnessPresent.value_counts()
# Out:
# No     15244
# Yes       87
# Name: WitnessPresent, dtype: int64

# %%
df.WitnessPresent = yesNoEncoder.transform(df.WitnessPresent)

# %%
df.AgentType.value_counts()
# Out:
# External    15094
# Internal      237
# Name: AgentType, dtype: int64

# %%
agentEncoder = LabelEncoder().fit(df.AgentType)
df.AgentType = agentEncoder.transform(df.AgentType)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15331 entries, 1 to 15419
# Data columns (total 33 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Month                 15331 non-null  int64
#  1   WeekOfMonth           15331 non-null  int64
#  2   DayOfWeek             15331 non-null  int64
#  3   Make                  15331 non-null  int64
#  4   AccidentArea          15331 non-null  int64
#  5   DayOfWeekClaimed      15331 non-null  int64
#  6   MonthClaimed          15331 non-null  int64
#  7   WeekOfMonthClaimed    15331 non-null  int64
#  8   Sex                   15331 non-null  int64
#  9   MaritalStatus         15331 non-null  int64
#  10  Age                   15331 non-null  int64
#  11  Fault                 15331 non-null  int64
#  12  PolicyType            15331 non-null  int64
#  13  VehicleCategory       15331 non-null  int64
#  14  VehiclePrice          15331 non-null  int64
# ...

# %%
df.NumberOfCars.value_counts()
# Out:
# 1 vehicle      14231
# 2 vehicles       707
# 3 to 4           370
# 5 to 8            21
# more than 8        2
# Name: NumberOfCars, dtype: int64

# %%
df = df[df['NumberOfCars']!='more than 8']

# %%
noOfCarsEncoder = LabelEncoder().fit(df.NumberOfCars)
df.NumberOfCars = noOfCarsEncoder.transform(df.NumberOfCars)

# %%
df.AddressChange_Claim.value_counts()
# Out:
# no change         14237
# 4 to 8 years        629
# 2 to 3 years        290
# 1 year              169
# under 6 months        4
# Name: AddressChange_Claim, dtype: int64

# %%
df = df[df['AddressChange_Claim']!='under 6 months']

# %%
addressChangeEncoder = LabelEncoder().fit(df.AddressChange_Claim)
df.AddressChange_Claim = addressChangeEncoder.transform(df.AddressChange_Claim)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15325 entries, 1 to 15419
# Data columns (total 33 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Month                 15325 non-null  int64
#  1   WeekOfMonth           15325 non-null  int64
#  2   DayOfWeek             15325 non-null  int64
#  3   Make                  15325 non-null  int64
#  4   AccidentArea          15325 non-null  int64
#  5   DayOfWeekClaimed      15325 non-null  int64
#  6   MonthClaimed          15325 non-null  int64
#  7   WeekOfMonthClaimed    15325 non-null  int64
#  8   Sex                   15325 non-null  int64
#  9   MaritalStatus         15325 non-null  int64
#  10  Age                   15325 non-null  int64
#  11  Fault                 15325 non-null  int64
#  12  PolicyType            15325 non-null  int64
#  13  VehicleCategory       15325 non-null  int64
#  14  VehiclePrice          15325 non-null  int64
# ...

# %%
df.NumberOfSuppliments.value_counts()
# Out:
# none           7005
# more than 5    3841
# 1 to 2         2475
# 3 to 5         2004
# Name: NumberOfSuppliments, dtype: int64

# %%
suppEncoder = LabelEncoder().fit(df.NumberOfSuppliments)
df.NumberOfSuppliments = suppEncoder.transform(df.NumberOfSuppliments)

# %%
df.head()
# Out:
#    Month  WeekOfMonth  DayOfWeek  Make  AccidentArea  DayOfWeekClaimed  \
# 1      4            3          6     5             1                 1
# 2     10            5          0     5             1                 4
# 3      6            2          2    12             0                 0
# 4      4            5          1     5             1                 5
# 5     10            4          0     5             1                 6
#
#    MonthClaimed  WeekOfMonthClaimed  Sex  MaritalStatus  ...  AgeOfVehicle  \
# 1             4                   4    1              2  ...             4
# 2             9                   2    1              1  ...             5
# 3             5                   1    1              1  ...             6
# 4             3                   2    0              2  ...             3
# 5             9                   1    1              2  ...             3
#
#    AgeOfPolicyHolder  PoliceReportFiled  WitnessPresent  AgentType  \
# ...

# %%
df
# Out:
#        Month  WeekOfMonth  DayOfWeek  Make  AccidentArea  DayOfWeekClaimed  \
# 1          4            3          6     5             1                 1
# 2         10            5          0     5             1                 4
# 3          6            2          2    12             0                 0
# 4          4            5          1     5             1                 5
# 5         10            4          0     5             1                 6
# ...      ...          ...        ...   ...           ...               ...
# 15415      9            4          0    12             1                 5
# 15416      9            5          4     9             1                 0
# 15417      9            5          4    12             0                 0
# 15418      2            1          1    12             1                 4
# 15419      2            2          6    12             1                 4
#
#        MonthClaimed  WeekOfMonthClaimed  Sex  MaritalStatus  ...  \
# ...

# %%
y = df['FraudFound_P']
x = df
x.drop(columns=['FraudFound_P'], inplace=True)

# %%
x.shape
# Out:
# (15325, 32)

# %%
from sklearn.model_selection import train_test_split

# %%
x, x_t, y, y_t = train_test_split(x,y, test_size=0.33, random_state=42)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from xgboost import XGBClassifier

from sklearn import metrics
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_validate
import time

# %%
classifiers = {
    'LogisticRegression' : LogisticRegression(),
    'GausianNaiveBayes' : GaussianNB(),
    'KNeighborsClassification' : KNeighborsClassifier(),
    'SVMClassification' : SVC(),
    'DecisionTreeClassifier': DecisionTreeClassifier(),
    'RandomForestClassifier': RandomForestClassifier(),
    'AdaBoostClassifier': AdaBoostClassifier(),
    "XGBClassifier": XGBClassifier(use_label_encoder=False, objective= 'binary:logistic',eval_metric='aucpr'),
}

# %%
df_models = pd.DataFrame(columns = ['model', 
                                    'run_time', 
                                    'avg_accy',
                                    'avg_accy_std',  
                                    'avg_recall',
                                    'avg_recall_std',
                                    'avg_precision',
                                    'avg_precision_std',
                                    'avg_f1',
                                    'avg_f1_std',
                                    'avg_matthew_corcoef',
                                    'avg_matthew_corcoef_std',
                                    'avg_roc_auc',
                                    'avg_roc_auc_std', 
                                     ])

scorer = {'accuracy_score':metrics.make_scorer(metrics.accuracy_score),
          'f1_score':metrics.make_scorer(metrics.f1_score),
          'recall_score':metrics.make_scorer(metrics.recall_score),
          'precision_score':metrics.make_scorer(metrics.average_precision_score),
          'matthew_corrcoef':metrics.make_scorer(metrics.matthews_corrcoef),
          'roc_auc_score':metrics.make_scorer(metrics.roc_auc_score) 
         }

# %%
for key in classifiers:
    print('*', key)
    start_time = time.time()
    classifier = classifiers[key]
    model = classifier.fit(x,y)
    cvs = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=42)
    cv_scores = cross_validate(model, x_t, y_t, cv=cvs, scoring = scorer)
    y_pred = model.predict(x_t)
    
    row = {
        'model': key,
        'run_time': format(round((time.time() - start_time)/60,2)),
        'avg_accy': cv_scores['test_accuracy_score'].mean(),
        'avg_accy_std': cv_scores['test_accuracy_score'].std(),
        'avg_recall': cv_scores['test_recall_score'].mean(),
        'avg_recall_std': cv_scores['test_recall_score'].std(),
        'avg_precision': cv_scores['test_precision_score'].mean(),
        'avg_precision_std': cv_scores['test_precision_score'].std(),
        'avg_f1': cv_scores['test_f1_score'].mean(),
        'avg_f1_std': cv_scores['test_f1_score'].std(),
        'avg_matthew_corcoef': cv_scores['test_matthew_corrcoef'].mean(),
        'avg_matthew_corcoef_std': cv_scores['test_matthew_corrcoef'].std(),
        'avg_roc_auc': cv_scores['test_roc_auc_score'].mean(),
        'avg_roc_auc_std': cv_scores['test_roc_auc_score'].std(),
    }
    
    df_models = df_models.append(row, ignore_index=True)
# Out:
# * LogisticRegression
# /home/16bit/Sooraj/TEST/MINI/env/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/16bit/Sooraj/TEST/MINI/env/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
df_models
# Out:
#                       model run_time  avg_accy avg_accy_std avg_recall  \
# 0        LogisticRegression      0.2   0.94227      0.00078        0.0
# 1         GausianNaiveBayes     0.01  0.889089     0.015199   0.148238
# 2  KNeighborsClassification      0.1  0.940622     0.002376   0.010307
# 3         SVMClassification     0.12   0.94227      0.00078        0.0
# 4    DecisionTreeClassifier     0.02  0.905496     0.009818   0.257969
# 5    RandomForestClassifier     0.31  0.942204     0.000834   0.001111
# 6        AdaBoostClassifier     0.22  0.937262     0.003172   0.008008
# 7             XGBClassifier     0.47  0.943522     0.004257    0.13364
#
#   avg_recall_std avg_precision avg_precision_std    avg_f1 avg_f1_std  \
# 0            0.0       0.05773           0.00078       0.0        0.0
# 1       0.060905      0.071146          0.016071  0.135171   0.058915
# 2       0.018088      0.063517          0.013253  0.019157    0.03368
# ...

# %%
model = classifiers['XGBClassifier'].fit(x.values,y)
model.score(x_t,y_t)
# Out:
# 0.9535389482008699

# %%
import pickle

# %%
with open('/home/16bit/Sooraj/TEST/MINI/Saved/dayEncoder.pkl', 'wb') as fh:
   pickle.dump(dayEncoder, fh)

with open('/home/16bit/Sooraj/TEST/MINI/Saved/monthEncoder.pkl', 'wb') as fh:
   pickle.dump(monthEncoder, fh)

with open('/home/16bit/Sooraj/TEST/MINI/Saved/makerEncoder.pkl', 'wb') as fh:
   pickle.dump(makerEncoder, fh)

with open('/home/16bit/Sooraj/TEST/MINI/Saved/areaEncoder.pkl', 'wb') as fh:
   pickle.dump(areaEncoder, fh)

with open('/home/16bit/Sooraj/TEST/MINI/Saved/sexEncoder.pkl', 'wb') as fh:
   pickle.dump(sexEncoder, fh)

with open('/home/16bit/Sooraj/TEST/MINI/Saved/maritalEncoder.pkl', 'wb') as fh:
   pickle.dump(maritalEncoder, fh)

with open('/home/16bit/Sooraj/TEST/MINI/Saved/policyEncoder.pkl', 'wb') as fh:
   pickle.dump(policyEncoder, fh)

with open('/home/16bit/Sooraj/TEST/MINI/Saved/policyHolderEncoder.pkl', 'wb') as fh:
   pickle.dump(policyHolderEncoder, fh)

with open('/home/16bit/Sooraj/TEST/MINI/Saved/vehCatEncoder.pkl', 'wb') as fh:
   pickle.dump(vehCatEncoder, fh)

with open('/home/16bit/Sooraj/TEST/MINI/Saved/vehPriceEncoder.pkl', 'wb') as fh:
   pickle.dump(vehPriceEncoder, fh)

with open('/home/16bit/Sooraj/TEST/MINI/Saved/daysCalimEncoder.pkl', 'wb') as fh:
   pickle.dump(daysCalimEncoder, fh)

with open('/home/16bit/Sooraj/TEST/MINI/Saved/baseEncoder.pkl', 'wb') as fh:
   pickle.dump(baseEncoder, fh)

with open('/home/16bit/Sooraj/TEST/MINI/Saved/pastClaimsEncoder.pkl', 'wb') as fh:
   pickle.dump(pastClaimsEncoder, fh)

with open('/home/16bit/Sooraj/TEST/MINI/Saved/vehicleAgeEncoder.pkl', 'wb') as fh:
   pickle.dump(vehicleAgeEncoder, fh)

with open('/home/16bit/Sooraj/TEST/MINI/Saved/policyHolderAgeEncoder.pkl', 'wb') as fh:
   pickle.dump(policyHolderAgeEncoder, fh)

with open('/home/16bit/Sooraj/TEST/MINI/Saved/yesNoEncoder.pkl', 'wb') as fh:
   pickle.dump(yesNoEncoder, fh)

with open('/home/16bit/Sooraj/TEST/MINI/Saved/agentEncoder.pkl', 'wb') as fh:
   pickle.dump(agentEncoder, fh)

with open('/home/16bit/Sooraj/TEST/MINI/Saved/noOfCarsEncoder.pkl', 'wb') as fh:
   pickle.dump(noOfCarsEncoder, fh)

with open('/home/16bit/Sooraj/TEST/MINI/Saved/addressChangeEncoder.pkl', 'wb') as fh:
   pickle.dump(addressChangeEncoder, fh)

with open('/home/16bit/Sooraj/TEST/MINI/Saved/suppEncoder.pkl', 'wb') as fh:
   pickle.dump(suppEncoder, fh)

with open('/home/16bit/Sooraj/TEST/MINI/Saved/model.pkl', 'wb') as fh:
   pickle.dump(model, fh)
